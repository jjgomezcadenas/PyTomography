# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from torchvision.transforms.functional import rotate
from pytomography.utils import rotate_detector_z
#device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using mps device

# %% [markdown]
# PyTomography is built around PyTorch, which uses the data type `torch.tensor` (very analogous to the `numpy.array`)

# %%
x = torch.tensor([2,3,4])
x**2
# Out:
# tensor([ 4,  9, 16])

# %% [markdown]
# All objects and images are stored using `torch.tensor`s. The shape of the tensor depends on the imaging modality
#
# * For SPECT, objects have shape `[batch_size, Lx, Ly, Lz]` and images have shape `[batch_size, Ltheta, Lr, Lz]`

# %%
x = torch.ones((1,128,128,128))
x.shape
# Out:
# torch.Size([1, 128, 128, 128])

# %% [markdown]
# #### Create an object:
# As an example of a simple object we can create a cylinder using a meshgrid

# %%
def cyl(grid_min=-1, grid_max=1, np=128, r=0.5, z=0.8):
    x = torch.linspace(grid_min,grid_max,np)
    xv, yv, zv = torch.meshgrid(x,x,x, indexing='ij')
    obj = (xv**2 + zv**2 < r**2) * (torch.abs(yv)<z)
    obj = obj.to(torch.float)
    return obj, x

# %%
def plot_cyl(x, obj, figsize=(10,3)):
    fig, _ = plt.subplots(1,3,figsize=figsize)
    plt.subplot(131)
    plt.pcolormesh(x,x,obj.sum(axis=0).T, cmap='Greys_r')
    plt.xlabel('y')
    plt.ylabel('z')
    plt.title('Coronal')
    plt.subplot(132)
    plt.pcolormesh(x,x,obj.sum(axis=1).T, cmap='Greys_r')
    plt.xlabel('x')
    plt.ylabel('z')
    plt.title('Sagittal')
    plt.subplot(133)
    plt.pcolormesh(x,x, obj.sum(axis=2).T, cmap='Greys_r')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Axial')
    fig.tight_layout()

# %%
ocl, xmc = cyl(grid_min=-1, grid_max=1, np=128, r=0.8, z=0.8)

# %%
ocl.shape
# Out:
# torch.Size([128, 128, 128])

# %%
plot_cyl(xmc, ocl)

# %% [markdown]
# #### Batch_size:
# We need to ensure we have the `batch_size` dimension

# %%
obj = ocl.unsqueeze(dim=0)
obj.shape
# Out:
# torch.Size([1, 128, 128, 128])

# %% [markdown]
# Let's plot from a coronal, sagital, and axial perspective

# %% [markdown]
# # Fundamental Operations

# %% [markdown]
# Now that we have a 3D object $f$, we may want to turn this into projections $g$ using
#
# $$g = Hf$$
#
# Assuming no attenuation, PSF modeling, scattering, we can model this by projecting the object at different angles (think of it like taking an X-Ray at a number of different angles)

# %% [markdown]
# ## Idea
#
# Rotate the object first, always project along the x-axis (Nb: dimension 0 = batch, 1, 2, 3 = x,y,z)

# %%
proj = obj.sum(axis=1)
proj.shape
# Out:
# torch.Size([1, 128, 128])

# %% [markdown]
# This is an projection

# %% [markdown]
# ## The Rotate Function

# %% [markdown]
# The object is a tensor with 4 dimensions (including batch size). We can use the rotate function, which rotates the object in the $xy$-plane so long as $x$ and $y$ are the final two dimensions
#
# * Right now $z$ is the last dimension
#
# So we need to transpose the array then rotate

# %%
beta = 45.0
phi = 270.0 - beta
obj_rotated = rotate(obj.permute(0,3,1,2), -phi).permute(0,2,3,1)

# %% [markdown]
# We rotate by $-\phi$ so that the detector angle is $\phi$

# %%
proj_45 = obj_rotated.sum(axis=1)
proj_45.shape
# Out:
# torch.Size([1, 128, 128])

# %% [markdown]
# All this functionality is contained in the `rotate_detector_z` function [here](https://pytomography.readthedocs.io/en/latest/_modules/pytomography/utils/helper_functions.html#rotate_detector_z).
#
# ```
# def rotate_detector_z(
#     x: torch.Tensor,
#     angles: torch.tensor,
#     mode: str = 'bilinear',
#     negative: bool = False):
# ```

# %%
beta_t = torch.tensor(beta).unsqueeze(0)

# %%
beta_t
# Out:
# tensor([45.])

# %%
beta_t.shape
# Out:
# torch.Size([1])

# %%
obj_45_p = rotate_detector_z(obj, beta_t, negative=False)

# %%
obj_45_n = rotate_detector_z(obj, beta_t, negative=True)

# %%
obj_45_.shape
# Out:
# torch.Size([1, 128, 128, 128])

# %%
proj_45_p = obj_45_p.sum(axis=1)
proj_45_p.shape
# Out:
# torch.Size([1, 128, 128])

# %%
plt.pcolormesh(proj_45_p[0].T, cmap='Greys')

# %%
proj_45_n = obj_45_n.sum(axis=1)
proj_45_n.shape
# Out:
# torch.Size([1, 128, 128])

# %%
plt.pcolormesh(proj_45_n[0].T, cmap='Greys')

# %% [markdown]
# This is equivalent to what we would call $g_{45^{\circ}}$ in the SPECT example of the manual [here](https://pytomography.readthedocs.io/en/latest/notebooks/conventions.html#Mappings). We can the compute $g = \sum_{\theta} g_{\theta} \otimes \hat{\theta}$ by computing these projections for a number of angles

# %%
angles = torch.arange(0,360.,3)

# %%
angles.shape
# Out:
# torch.Size([120])

# %%
image = torch.zeros((1,len(angles),128,128))

# %%
image.shape
# Out:
# torch.Size([1, 120, 128, 128])

# %%
image[:,1].shape
# Out:
# torch.Size([1, 128, 128])

# %%
image[:,2].shape
# Out:
# torch.Size([1, 128, 128])

# %%
image[:,119].shape
# Out:
# torch.Size([1, 128, 128])

# %%
for i,angle in enumerate(angles):
    object_i = rotate_detector_z(obj,angle)
    image[:,i] = object_i.sum(axis=1)

# %% [markdown]
# Now we can look at the image

# %%
plt.pcolormesh(image[0,:,:,70].T)
plt.xlabel('Angle')
plt.ylabel('r')
# Out:
# Text(0, 0.5, 'r')

# %%
def plot_proj16(image, pi =64, figsize=(10,3)):
    fig, axs = plt.subplots(4,4, figsize=figsize)
    for i in range(0,4):
        for j in range(0,4):
            #print(pi+i+j)
            axs[i, j].pcolormesh(image[0,:,:,pi+i+j].T)
    
    fig.tight_layout()

# %%
plot_proj16(image, pi =64, figsize=(10,6))
